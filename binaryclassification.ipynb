# %%
from tensorflow import keras

# %%
class SimpleDense(keras.layers.Layer): 
  def __init__(self, units, activation=None):
    super().__init__()
    self.units = units
    self.activation = activation

# %%
def build(self, input_shape): 
  input_dim = input_shape[-1]
  self.W = self.add_weight(shape=(input_dim, self.units), 
  initializer="random_normal")
  self.b = self.add_weight(shape=(self.units,),
  initializer="zeros")

# %%
def call(self, inputs): 
  y = tf.matmul(inputs, self.W) + self.b
  if self.activation is not None:
    y = self.activation(y)
  return y

# %%
from tensorflow.keras.datasets import imdb
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17465344/17464789 [==============================] - 0s 0us/step
# 17473536/17464789 [==============================] - 0s 0us/step

# %%
train_data[0]
# Out:
# [1,
#  14,
#  22,
#  16,
#  43,
#  530,
#  973,
#  1622,
#  1385,
#  65,
#  458,
#  4468,
#  66,
#  3941,
#  4,
#  173,
#  36,
#  256,
#  5,
#  25,
#  100,
#  43,
#  838,
#  112,
#  50,
#  670,
#  2,
#  9,
#  35,
#  480,
#  284,
#  5,
#  150,
#  4,
#  172,
#  112,
#  167,
#  2,
#  336,
#  385,
#  39,
#  4,
#  172,
#  4536,
#  1111,
#  17,
#  546,
#  38,
#  13,
#  447,
#  4,
#  192,
#  50,
#  16,
#  6,
#  147,
#  2025,
#  19,
#  14,
#  22,
#  4,
#  1920,
#  4613,
#  469,
#  4,
#  22,
#  71,
#  87,
#  12,
#  16,
#  43,
#  530,
#  38,
#  76,
#  15,
#  13,
#  1247,
#  4,
#  22,
#  17,
#  515,
#  17,
#  12,
#  16,
#  626,
#  18,
#  2,
#  5,
#  62,
#  386,
#  12,
#  8,
#  316,
#  8,
#  106,
#  5,
#  4,
#  2223,
#  5244,
#  16,
#  480,
#  66,
#  3785,
#  33,
#  4,
#  130,
#  12,
#  16,
#  38,
#  619,
#  5,
#  25,
#  124,
#  51,
#  36,
#  135,
#  48,
#  25,
#  1415,
#  33,
#  6,
#  22,
#  12,
#  215,
#  28,
#  77,
#  52,
#  5,
#  14,
#  407,
#  16,
#  82,
#  2,
#  8,
#  4,
#  107,
#  117,
#  5952,
#  15,
#  256,
#  4,
#  2,
#  7,
#  3766,
#  5,
#  723,
#  36,
#  71,
#  43,
#  530,
#  476,
#  26,
#  400,
#  317,
#  46,
#  7,
#  4,
#  2,
#  1029,
#  13,
#  104,
#  88,
#  4,
#  381,
#  15,
#  297,
#  98,
#  32,
#  2071,
#  56,
#  26,
#  141,
#  6,
#  194,
#  7486,
#  18,
#  4,
#  226,
#  22,
#  21,
#  134,
#  476,
#  26,
#  480,
#  5,
#  144,
#  30,
#  5535,
#  18,
#  51,
#  36,
#  28,
#  224,
#  92,
#  25,
#  104,
#  4,
#  226,
#  65,
#  16,
#  38,
#  1334,
#  88,
#  12,
#  16,
#  283,
#  5,
#  16,
#  4472,
#  113,
#  103,
#  32,
#  15,
#  16,
#  5345,
#  19,
#  178,
#  32]

# %%
train_labels[0]
# Out:
# 1

# %%
max([max(sequence) for sequence in train_data])
# Out:
# 9999

# %%
word_index = imdb.get_word_index() 
reverse_word_index = dict(
 [(value, key) for (key, value) in word_index.items()])
decoded_review = " ".join(
 [reverse_word_index.get(i - 3, "?") for i in train_data[0]])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb_word_index.json
# 1646592/1641221 [==============================] - 0s 0us/step
# 1654784/1641221 [==============================] - 0s 0us/step

# %%
import numpy as np 
def vectorize_sequences(sequences, dimension=10000): 
  results = np.zeros((len(sequences), dimension))
  for i, sequence in enumerate(sequences):
    for j in sequence:
        results[i, j] = 1. 
  return results
x_train = vectorize_sequences(train_data) 
x_test = vectorize_sequences(test_data)

# %%
y_train = np.asarray(train_labels).astype("float32")
y_test = np.asarray(test_labels).astype("float32")

# %%
from tensorflow import keras 
from tensorflow.keras import layers
model = keras.Sequential([
 layers.Dense(16, activation="relu"),
 layers.Dense(16, activation="relu"),
 layers.Dense(1, activation="sigmoid")
])

# %%
model.compile(optimizer="rmsprop",
 loss="binary_crossentropy",
 metrics=["accuracy"])

# %%
x_val = x_train[:10000]
partial_x_train = x_train[10000:]
y_val = y_train[:10000]
partial_y_train = y_train[10000:]

# %%
history = model.fit(partial_x_train,
 partial_y_train,
 epochs=20,
 batch_size=512,
 validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 30/30 [==============================] - 3s 61ms/step - loss: 0.5021 - accuracy: 0.7939 - val_loss: 0.3729 - val_accuracy: 0.8748
# Epoch 2/20
# 30/30 [==============================] - 1s 35ms/step - loss: 0.2933 - accuracy: 0.9074 - val_loss: 0.2984 - val_accuracy: 0.8879
# Epoch 3/20
# 30/30 [==============================] - 1s 34ms/step - loss: 0.2191 - accuracy: 0.9278 - val_loss: 0.2863 - val_accuracy: 0.8864
# Epoch 4/20
# 30/30 [==============================] - 1s 35ms/step - loss: 0.1719 - accuracy: 0.9426 - val_loss: 0.2762 - val_accuracy: 0.8907
# Epoch 5/20
# 30/30 [==============================] - 2s 52ms/step - loss: 0.1394 - accuracy: 0.9554 - val_loss: 0.3040 - val_accuracy: 0.8771
# Epoch 6/20
# 30/30 [==============================] - 1s 45ms/step - loss: 0.1138 - accuracy: 0.9655 - val_loss: 0.2952 - val_accuracy: 0.8855
# Epoch 7/20
# 30/30 [==============================] - 1s 35ms/step - loss: 0.0930 - accuracy: 0.9723 - val_loss: 0.3602 - val_accuracy: 0.8694
# Epoch 8/20
# 30/30 [==============================] - 1s 35ms/step - loss: 0.0750 - accuracy: 0.9796 - val_loss: 0.3472 - val_accuracy: 0.8808
# Epoch 9/20
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0619 - accuracy: 0.9836 - val_loss: 0.3979 - val_accuracy: 0.8680
# Epoch 10/20
# 30/30 [==============================] - 1s 35ms/step - loss: 0.0522 - accuracy: 0.9858 - val_loss: 0.3867 - val_accuracy: 0.8780
# Epoch 11/20
# 30/30 [==============================] - 1s 35ms/step - loss: 0.0388 - accuracy: 0.9913 - val_loss: 0.4578 - val_accuracy: 0.8643
# Epoch 12/20
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0356 - accuracy: 0.9915 - val_loss: 0.4478 - val_accuracy: 0.8744
# Epoch 13/20
# 30/30 [==============================] - 1s 35ms/step - loss: 0.0224 - accuracy: 0.9962 - val_loss: 0.5525 - val_accuracy: 0.8644
# Epoch 14/20
# 30/30 [==============================] - 1s 35ms/step - loss: 0.0215 - accuracy: 0.9957 - val_loss: 0.5070 - val_accuracy: 0.8730
# Epoch 15/20
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0177 - accuracy: 0.9968 - val_loss: 0.5404 - val_accuracy: 0.8707
# Epoch 16/20
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0095 - accuracy: 0.9995 - val_loss: 0.5877 - val_accuracy: 0.8693
# Epoch 17/20
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0089 - accuracy: 0.9995 - val_loss: 0.6118 - val_accuracy: 0.8692
# Epoch 18/20
# 30/30 [==============================] - 1s 39ms/step - loss: 0.0090 - accuracy: 0.9987 - val_loss: 0.6527 - val_accuracy: 0.8675
# Epoch 19/20
# 30/30 [==============================] - 1s 35ms/step - loss: 0.0066 - accuracy: 0.9991 - val_loss: 0.6813 - val_accuracy: 0.8682
# Epoch 20/20
# 30/30 [==============================] - 1s 35ms/step - loss: 0.0029 - accuracy: 0.9999 - val_loss: 0.7088 - val_accuracy: 0.8673

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
import matplotlib.pyplot as plt
history_dict = history.history
loss_values = history_dict["loss"]
val_loss_values = history_dict["val_loss"]
epochs = range(1, len(loss_values) + 1)
plt.plot(epochs, loss_values, "bo", label="Training loss")
plt.plot(epochs, val_loss_values, "b", label="Validation loss") 
plt.title("Training and validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.clf()
acc = history_dict["accuracy"]
val_acc = history_dict["val_accuracy"]
plt.plot(epochs, acc, "bo", label="Training acc")
plt.plot(epochs, val_acc, "b", label="Validation acc")
plt.title("Training and validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
model = keras.Sequential([
 layers.Dense(16, activation="relu"),
 layers.Dense(16, activation="relu"),
 layers.Dense(1, activation="sigmoid")
])
model.compile(optimizer="rmsprop",
 loss="binary_crossentropy",
 metrics=["accuracy"])
model.fit(x_train, y_train, epochs=4, batch_size=512)
results = model.evaluate(x_test, y_test)
# Out:
# Epoch 1/4
# 49/49 [==============================] - 2s 28ms/step - loss: 0.4507 - accuracy: 0.8230
# Epoch 2/4
# 49/49 [==============================] - 1s 28ms/step - loss: 0.2562 - accuracy: 0.9112
# Epoch 3/4
# 49/49 [==============================] - 1s 28ms/step - loss: 0.1977 - accuracy: 0.9302
# Epoch 4/4
# 49/49 [==============================] - 1s 28ms/step - loss: 0.1663 - accuracy: 0.9410
# 782/782 [==============================] - 2s 2ms/step - loss: 0.2935 - accuracy: 0.8839

# %%
results
# Out:
# [0.2934849262237549, 0.8838800191879272]

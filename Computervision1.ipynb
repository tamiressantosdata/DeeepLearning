# %%
from keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
train_labels
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
len(test_labels)
# Out:
# 10000

# %%
from tensorflow import keras
from tensorflow.keras import layers
model = keras.Sequential([
 layers.Dense(512, activation="relu"),
 layers.Dense(10, activation="softmax")
])

# %%
model.compile(optimizer="rmsprop",
 loss="sparse_categorical_crossentropy",
 metrics=["accuracy"])

# %%
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype("float32") / 255

# %%
model.fit(train_images, train_labels, epochs=5, batch_size=128)
# Out:
# Epoch 1/5
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2534 - accuracy: 0.9265
# Epoch 2/5
# 469/469 [==============================] - 5s 10ms/step - loss: 0.1034 - accuracy: 0.9696
# Epoch 3/5
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0686 - accuracy: 0.9794
# Epoch 4/5
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0494 - accuracy: 0.9850
# Epoch 5/5
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0370 - accuracy: 0.9890

# %%
test_digits = test_images[0:10]
predictions = model.predict(test_digits)
predictions[0]
# Out:
# array([2.5069968e-09, 2.4567468e-11, 5.3211488e-07, 1.4343213e-04,
#        1.8857084e-12, 1.5444305e-09, 2.9843150e-15, 9.9985301e-01,
#        9.9927945e-08, 3.0080050e-06], dtype=float32)

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0659 - accuracy: 0.9794

# %%
print(f"test_acc: {test_acc}")
# Out:
# test_acc: 0.9793999791145325

# %%
from tensorflow.keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
import matplotlib.pyplot as plt
digit = train_images[4]
plt.imshow(digit, cmap=plt.cm.binary)
plt.show()
